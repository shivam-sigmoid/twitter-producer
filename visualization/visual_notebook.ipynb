# %%
# Api 3 and 4 Visualization

# %%
import sys
sys.path.append("../")

# %%
from app.database import Database
col = Database.create_db_connection("tweets")

# %%
tweets = col.find()

# %%
from server.utility_functions import Utils

# %%
list_word_count = Utils.most_common_words(tweets)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shivamraj/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# %%
print(list_word_count)
# Out:
# [('people', 9916), ('like', 5978), ('vaccine', 5245), ('dont', 5083), ('still', 4925), ('one', 4737), ('help', 4545), ('family', 4503), ('im', 4328), ('cases', 4297), ('please', 4249), ('new', 4198), ('time', 4027), ('know', 3830), ('would', 3762), ('back', 3456), ('got', 3374), ('many', 3299), ('health', 3290), ('need', 3275), ('years', 3148), ('deaths', 3090), ('even', 3003), ('also', 2969), ('long', 2953), ('today', 2942), ('day', 2852), ('think', 2803), ('children', 2792), ('go', 2744), ('never', 2695), ('pandemic', 2664), ('2', 2605), ('last', 2586), ('going', 2517), ('cant', 2409), ('donation', 2407), ('right', 2399), ('much', 2354), ('work', 2352), ('news', 2342), ('vaccines', 2334), ('week', 2311), ('better', 2304), ('say', 2293), ('good', 2292), ('corona', 2285), ('china', 2282), ('government', 2265), ('well', 2260), ('want', 2251), ('could', 2247), ('make', 2215), ('first', 2212), ('see', 2199), ('thats', 2186), ('via', 2170), ('since', 2166), ('due', 2132), ('world', 2129), ('may', 2120), ('live', 2115), ('two', 2070), ('life', 2062), ('didnt', 2024), ('care', 2018), ('support', 1987), ('virus', 1984), ('death', 1977), ('money', 1951), ('died', 1947), ('give', 1935), ('getting', 1921), ('take', 1915), ('really', 1847), ('said', 1847), ('lockdown', 1832), ('come', 1827), ('every', 1826), ('part', 1819), ('feel', 1813), ('year', 1809), ('shanghai', 1796), ('mask', 1794), ('nothing', 1782), ('positive', 1769), ('fort', 1757), ('detrick', 1731), ('way', 1702), ('vaccinated', 1653), ('without', 1651), ('doesnt', 1647), ('india', 1640), ('test', 1632), ('1', 1601), ('stop', 1594), ('2020', 1588), ('country', 1583), ('report', 1579), ('home', 1573)]

# %%
def make_dictionary(li):
    dic=dict()
    for k,v in li:
        dic[k]=int(v)
    return dic

# %%
word_count = make_dictionary(list_word_count)

# %%
print(word_count)
# Out:
# {'people': 9916, 'like': 5978, 'vaccine': 5245, 'dont': 5083, 'still': 4925, 'one': 4737, 'help': 4545, 'family': 4503, 'im': 4328, 'cases': 4297, 'please': 4249, 'new': 4198, 'time': 4027, 'know': 3830, 'would': 3762, 'back': 3456, 'got': 3374, 'many': 3299, 'health': 3290, 'need': 3275, 'years': 3148, 'deaths': 3090, 'even': 3003, 'also': 2969, 'long': 2953, 'today': 2942, 'day': 2852, 'think': 2803, 'children': 2792, 'go': 2744, 'never': 2695, 'pandemic': 2664, '2': 2605, 'last': 2586, 'going': 2517, 'cant': 2409, 'donation': 2407, 'right': 2399, 'much': 2354, 'work': 2352, 'news': 2342, 'vaccines': 2334, 'week': 2311, 'better': 2304, 'say': 2293, 'good': 2292, 'corona': 2285, 'china': 2282, 'government': 2265, 'well': 2260, 'want': 2251, 'could': 2247, 'make': 2215, 'first': 2212, 'see': 2199, 'thats': 2186, 'via': 2170, 'since': 2166, 'due': 2132, 'world': 2129, 'may': 2120, 'live': 2115, 'two': 2070, 'life': 2062, 'didnt': 2024, 'care': 2018, 'support': 1987, 'virus': 1984, 'death': 1977, 'money': 1951, 'died': 1947, 'give': 1935, 'getting': 1921, 'take': 1915, 'really': 1847, 'said': 1847, 'lockdown': 1832, 'come': 1827, 'every': 1826, 'part': 1819, 'feel': 1813, 'year': 1809, 'shanghai': 1796, 'mask': 1794, 'nothing': 1782, 'positive': 1769, 'fort': 1757, 'detrick': 1731, 'way': 1702, 'vaccinated': 1653, 'without': 1651, 'doesnt': 1647, 'india': 1640, 'test': 1632, '1': 1601, 'stop': 1594, '2020': 1588, 'country': 1583, 'report': 1579, 'home': 1573}

# %%
def make_barplot_using_seaborn(word_count):
    plt.figure(figsize=(18,18))
    sns.barplot(list(word_count.keys()), list(word_count.values()))
    plt.show()

# %%
def make_wordcloud(word_count):
    wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_count)
    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)

# %%
def make_barplot_using_matplotlib(word_count):
    plt.figure(figsize=(18,18))
    plt.bar(*zip(*word_count.items()))
    plt.show()

# %%
make_barplot_using_seaborn(word_count)
# Out:
# /Users/shivamraj/Documents/Project/venv/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
make_wordcloud(word_count)

# %%
make_barplot_using_matplotlib(word_count)

# %%
def make_graph(my_dict):
    plt.figure(figsize=(18,18))
    myList = my_dict.items()
    myList = sorted(myList) 
    x, y = zip(*myList) 

    plt.plot(x, y)
    plt.show()

# %%
make_graph(word_count)

# %%
def plot_pie_chart(your_data):
    plt.figure(figsize=(18,18))
    plt.pie([float(your_data[v]) for v in your_data], labels=[str(k) for k in your_data], autopct='%1.1f%%')
    plt.show()

# %%
plot_pie_chart(word_count)
